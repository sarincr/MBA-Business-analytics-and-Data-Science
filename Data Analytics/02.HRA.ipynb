# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("HRDataset_v14.csv")

# %%
df.head()
# Out:
#               Employee_Name  ...  YearsWithCurrManager
# 0       Adinolfi, Wilson  K  ...                     5
# 1  Ait Sidi, Karthikeyan     ...                     7
# 2         Akinkuolie, Sarah  ...                     0
# 3              Alagbe,Trina  ...                     0
# 4          Anderson, Carol   ...                     2
#
# [5 rows x 59 columns]

# %%
# Determine the total number of people who are Sales Executive

# %%
df.loc[df['Position'] == "Production Technician I"].count()
# Out:
# Employee_Name                 137
# EmpID                         137
# MarriedID                     137
# MaritalStatusID               137
# Gender                        137
# EmpStatusID                   137
# DeptID                        137
# PerfScoreID                   137
# FromDiversityJobFairID        137
# Salary                        137
# Termd                         137
# PositionID                    137
# Position                      137
# State                         137
# Zip                           137
# DOB                           137
# Sex                           137
# MaritalDesc                   137
# CitizenDesc                   137
# HispanicLatino                137
# RaceDesc                      137
# DateofHire                    137
# DateofTermination              52
# TermReason                    137
# EmploymentStatus              137
# Department                    137
# ManagerName                   137
# ...

# %%
#Determine the number of males.

# %%
df.loc[df['Gender'] == "Male"].count()
# Out:
# Employee_Name                 193
# EmpID                         193
# MarriedID                     193
# MaritalStatusID               193
# Gender                        194
# EmpStatusID                   193
# DeptID                        193
# PerfScoreID                   193
# FromDiversityJobFairID        193
# Salary                        193
# Termd                         193
# PositionID                    193
# Position                      193
# State                         193
# Zip                           193
# DOB                           193
# Sex                           193
# MaritalDesc                   193
# CitizenDesc                   193
# HispanicLatino                193
# RaceDesc                      193
# DateofHire                    193
# DateofTermination              64
# TermReason                    193
# EmploymentStatus              193
# Department                    193
# ManagerName                   193
# ...

# %%
#Find persons who are employed under “Michael Albert”.
df.loc[df['ManagerName'] == "Michael Albert"].count()
# Out:
# Employee_Name                 22
# EmpID                         22
# MarriedID                     22
# MaritalStatusID               22
# Gender                        22
# EmpStatusID                   22
# DeptID                        22
# PerfScoreID                   22
# FromDiversityJobFairID        22
# Salary                        22
# Termd                         22
# PositionID                    22
# Position                      22
# State                         22
# Zip                           22
# DOB                           22
# Sex                           22
# MaritalDesc                   22
# CitizenDesc                   22
# HispanicLatino                22
# RaceDesc                      22
# DateofHire                    22
# DateofTermination              9
# TermReason                    22
# EmploymentStatus              22
# Department                    22
# ManagerName                   22
# ManagerID                     22
# ...

# %%
#List active employee names.
df['Employee_Name'].loc[df['EmploymentStatus'] == "Active"]
# Out:
# 0      Adinolfi, Wilson  K
# 3             Alagbe,Trina
# 5        Anderson, Linda
# 6          Andreola, Colby
# 7              Athwal, Sam
#               ...
# 305          Wolk, Hang  T
# 306         Woodson, Jason
# 308       Zamora, Jennifer
# 309            Zhou, Julia
# 310          Zima, Colleen
# Name: Employee_Name, Length: 207, dtype: object

# %%
#List active employee names who are married
df.loc[(df['EmploymentStatus'] == "Active" ) & (df['MaritalDesc'] == "Married") ]
# Out:
#          Employee_Name    EmpID  ...  YearsSinceLastPromotion  YearsWithCurrManager
# 3         Alagbe,Trina  10088.0  ...                        3                     0
# 16    Beak, Kimberly    10023.0  ...                        0                     5
# 22       Billis, Helen  10003.0  ...                        2                    11
# 26   Boutwell, Bonalyn  10081.0  ...                        6                     7
# 29          Brown, Mia  10238.0  ...                        2                     1
# ..                 ...      ...  ...                      ...                   ...
# 271   Sullivan, Kissy   10158.0  ...                        9                     9
# 272  Sullivan, Timothy  10117.0  ...                        0                     4
# 275       Tannen, Biff  10173.0  ...                        0                     2
# 287      Turpin, Jumil  10045.0  ...                        1                     2
# ...

# %%
#Find a US citizen earning less than $60,000. 
df['Salary'].loc[(df['EmploymentStatus'] == "Active" ) & (df['CitizenDesc'] == "US Citizen") ]>6000
# Out:
# 0      True
# 3      True
# 5      True
# 6      True
# 7      True
#        ...
# 305    True
# 306    True
# 308    True
# 309    True
# 310    True
# Name: Salary, Length: 199, dtype: bool

# %%
#Find a active employees earning less than $60,000. 
for k in df.index :
  if  (df.loc[k,'EmploymentStatus'] == "Active" ) & (df.loc[k,'Salary']>6000):
    print(df.loc[k,'Employee_Name'])
# Out:
# Adinolfi, Wilson  K
# Alagbe,Trina
# Anderson, Linda
# Andreola, Colby
# Athwal, Sam
# Bachiochi, Linda
# Bacong, Alejandro
# Barbossa, Hector
# Barone, Francesco  A
# Beak, Kimberly
# Beatrice, Courtney
# Becker, Scott
# Bernstein, Sean
# Biden, Lowan  M
# Billis, Helen
# Blount, Dianna
# Boutwell, Bonalyn
# Brown, Mia
# Buccheri, Joseph
# Bugali, Josephine
# Burke, Joelle
# Burkett, Benjamin
# Cady, Max
# Candie, Calvin
# Carabbio, Judith
# Carey, Michael
# Carr, Claudia  N
# Carter, Michelle
# Chace, Beatrice
# Champaigne, Brian
# Chan, Lin
# Chang, Donovan  E
# Chigurh, Anton
# Cierpiszewski, Caroline
# Clayton, Rick
# Clukey, Elijian
# Cockel, James
# Corleone, Michael
# Corleone, Vito
# Cornett, Lisa
# Costello, Frank
# Crimmings,   Jean
# Cross, Noah
# Daneault, Lynn
# Daniele, Ann
# Darson, Jene'ya
# Davis, Daniel
# Dee, Randy
# Del Bosque, Keyla
# Delarge, Alex
# Desimone, Carl
# DeVito, Tommy
# Dickinson, Geoff
# Dietrich, Jenna
# DiNocco, Lily
# Dobrin, Denisa  S
# ...

# %%
#Find the best Production Technician II based on EngagementSurvey
df['EngagementSurvey'].max()
# Out:
# 5.0

# %%
#Find the best Production Technician II based on EngagementSurvey
for k in df.index :
  if  (df.loc[k,'Position'] == "Production Technician I" ) & (df.loc[k,'EngagementSurvey']== df['EngagementSurvey'].max()) :
    print(df.loc[k,'Employee_Name'])
# Out:
# Anderson, Carol
# Anderson, Linda
# Athwal, Sam
# Barton, Nader
# Bates, Norman
# Beatrice, Courtney
# Bernstein, Sean
# Billis, Helen
# Chace, Beatrice
# Darson, Jene'ya
# DeGweck,  James
# Eaton, Marianne
# Estremera, Miguel
# Fidelia,  Libby
# Gordon, David
# Gross, Paula
# Jhaveri, Sneha
# Langton, Enrico
# Lydon, Allison
# Lynch, Lindsay
# Maurice, Shana
# Medeiros, Jennifer
# Newman, Richard
# Osturnka, Adeel
# Pham, Hong
# Rhoads, Thomas
# Robinson, Alain
# Rose, Ashley
# Rossetti, Bruno
# Sewkumar, Nori
# Whittier, Scott
# Wilber, Barry

# %%
#Find the positions which are drawing maximum Salary 
for k in df.index :
  if  (df.loc[k,'Salary']== df['Salary'].max()) :
    print(df.loc[k,'Position'])
# Out:
# President & CEO

# %%
#Find the positions which are drawing  lower than average salary
for k in df.index :
  if  (df.loc[k,'Salary'] < df['Salary'].mean()) :
    print(df.loc[k,'Position'])
# Out:
# Production Technician I
# Production Technician II
# Production Technician I
# Production Technician I
# Production Technician I
# Production Technician I
# Production Technician I
# IT Support
# Production Technician I
# Production Technician I
# Production Technician I
# Production Technician I
# Production Technician I
# Production Technician I
# Production Technician I
# Production Technician I
# Production Technician I
# Production Technician I
# Production Technician II
# Production Technician II
# Production Technician I
# Accountant I
# Production Technician II
# Production Technician I
# Production Technician II
# Production Technician II
# Production Technician I
# Production Technician I
# Production Technician I
# Production Technician I
# Area Sales Manager
# Production Technician I
# Production Technician I
# IT Support
# Production Technician II
# Production Technician II
# Production Technician I
# Production Technician I
# Production Technician I
# ...

# %%
#Find the persons which are drawing  lower than average salary
for k in df.index :
  if  (df.loc[k,'Salary'] < df['Salary'].mean()) :
    print(df.loc[k,'Employee_Name'])
# Out:
# Adinolfi, Wilson  K
# Akinkuolie, Sarah
# Alagbe,Trina
# Anderson, Carol
# Anderson, Linda
# Athwal, Sam
# Bachiochi, Linda
# Bacong, Alejandro
# Baczenski, Rachael
# Barbara, Thomas
# Barone, Francesco  A
# Barton, Nader
# Bates, Norman
# Beatrice, Courtney
# Becker, Scott
# Bernstein, Sean
# Biden, Lowan  M
# Billis, Helen
# Blount, Dianna
# Bondwell, Betsy
# Brill, Donna
# Brown, Mia
# Buccheri, Joseph
# Bugali, Josephine
# Burke, Joelle
# Burkett, Benjamin
# Carey, Michael
# Chace, Beatrice
# Chan, Lin
# Chang, Donovan  E
# Chigurh, Anton
# Chivukula, Enola
# Cierpiszewski, Caroline
# Clayton, Rick
# Cloninger, Jennifer
# Close, Phil
# Clukey, Elijian
# Cockel, James
# Cole, Spencer
# Corleone, Michael
# Cornett, Lisa
# Crimmings,   Jean
# Daneault, Lynn
# Darson, Jene'ya
# Davis, Daniel
# Dee, Randy
# DeGweck,  James
# Delarge, Alex
# Demita, Carla
# Desimone, Carl
# Dickinson, Geoff
# Dietrich, Jenna
# DiNocco, Lily
# Dobrin, Denisa  S
# Dunne, Amy
# Eaton, Marianne
# ...

# %%
#Find the persons which are drawing  lower than average salary and are not satisfactory 
for k in df.index :
  if  (df.loc[k,'Salary'] < df['Salary'].mean()) &  (df.loc[k,'JobSatisfaction'] < df['JobSatisfaction'].mean())  :
    print(df.loc[k,'Employee_Name'])
# Out:
# Anderson, Carol
# Baczenski, Rachael
# Bates, Norman
# Biden, Lowan  M
# Billis, Helen
# Bondwell, Betsy
# Brown, Mia
# Carey, Michael
# Chace, Beatrice
# Cierpiszewski, Caroline
# Cockel, James
# Cole, Spencer
# Cornett, Lisa
# Davis, Daniel
# Delarge, Alex
# Demita, Carla
# Dickinson, Geoff
# Dietrich, Jenna
# DiNocco, Lily
# Dunne, Amy
# Estremera, Miguel
# Fernandes, Nilson
# Fidelia,  Libby
# Galia, Lisa
# Garcia, Raul
# Gaul, Barbara
# Girifalco, Evelyn
# Gold, Shenice
# Good, Susan
# Gosciminski, Phylicia
# Handschiegl, Joanne
# Harrison, Kara
# Homberger, Adrienne  J
# Hutter, Rosalie
# Jacobi, Hannah
# Johnston, Yen
# Kampew, Donysha
# Keatts, Kramer
# Khemmich, Bartholemew
# Kinsella, Kathleen
# Knapp, Bradley  J
# Latif, Mohammed
# Lecter, Hannibal
# Lindsay, Leonara
# Lundy, Susan
# Lydon, Allison
# Lynch, Lindsay
# MacLennan, Samuel
# Mancuso, Karen
# Maurice, Shana
# Carthy, B'rigit
# McKinzie, Jac
# Meads, Elizabeth
# Monkfish, Erasumus
# Myers, Michael
# ...

# %%
for k in df.index :
  if  (df.loc[k,'Salary'] == df['Salary'].min()) &  (df.loc[k,'JobSatisfaction'] == df['JobSatisfaction'].max())  :
    print(df.loc[k,'Employee_Name'])

# %%
for k in df.index :
  if  (df.loc[k,'Salary'] == df['Salary'].min()) &  (df.loc[k,'JobSatisfaction'] >= df['JobSatisfaction'].min())  :
    print(df.loc[k,'Employee_Name'])
# Out:
# Zima, Colleen

# %%
for k in df.index :
  if  (df.loc[k,'Salary'] < df['Salary'].mean()) &  (df.loc[k,'JobSatisfaction'] >= 2)  :
    print(df.loc[k,'Employee_Name'])
# Out:
# Adinolfi, Wilson  K
# Akinkuolie, Sarah
# Alagbe,Trina
# Anderson, Carol
# Anderson, Linda
# Athwal, Sam
# Bachiochi, Linda
# Bacong, Alejandro
# Baczenski, Rachael
# Barbara, Thomas
# Barone, Francesco  A
# Barton, Nader
# Beatrice, Courtney
# Becker, Scott
# Bernstein, Sean
# Billis, Helen
# Blount, Dianna
# Brill, Donna
# Buccheri, Joseph
# Bugali, Josephine
# Burke, Joelle
# Burkett, Benjamin
# Chan, Lin
# Chang, Donovan  E
# Chigurh, Anton
# Chivukula, Enola
# Cierpiszewski, Caroline
# Clayton, Rick
# Cloninger, Jennifer
# Close, Phil
# Clukey, Elijian
# Corleone, Michael
# Crimmings,   Jean
# Daneault, Lynn
# Darson, Jene'ya
# Dee, Randy
# DeGweck,  James
# Desimone, Carl
# Dickinson, Geoff
# Dietrich, Jenna
# DiNocco, Lily
# Dobrin, Denisa  S
# Dunne, Amy
# Eaton, Marianne
# Engdahl, Jean
# England, Rex
# Erilus, Angela
# Estremera, Miguel
# Evensen, April
# Fancett, Nicole
# Ferguson, Susan
# Fernandes, Nilson
# Fett, Boba
# Fidelia,  Libby
# Foreman, Tanya
# Fraval, Maruk
# ...

# %%
# Fine the relation between DistanceFromHome and Salary 
plt.scatter(df['DistanceFromHome'], df['Salary'])

# %%
# Find the relation between DistanceFromHome and employee satisfaction 
plt.scatter(df['MonthlyIncome'], df['JobSatisfaction'])

# %%
df1=df.sort_values(by=['EmpID'], ascending=False)
df1
# Out:
#            Employee_Name  ...  YearsWithCurrManager
# 64            Dee, Randy  ...                     8
# 69       Desimone, Carl   ...                     0
# 91            Fett, Boba  ...                     0
# 90   Fernandes, Nilson    ...                    11
# 267   Stansfield, Norman  ...                     5
# ..                   ...  ...                   ...
# 174       Lynch, Lindsay  ...                     3
# 22         Billis, Helen  ...                    11
# 5      Anderson, Linda    ...                     6
# 36        Candie, Calvin  ...                     2
# 311                  NaN  ...                    11
#
# [312 rows x 59 columns]

# %%
print( df1['PerformanceRating'])
# Out:
# 64     3
# 69     3
# 91     4
# 90     4
# 267    3
#       ..
# 174    3
# 22     3
# 5      3
# 36     3
# 311    3
# Name: PerformanceRating, Length: 312, dtype: int64
